# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("fake_news_data.csv")

# %%
df.head()
# Out:
#                                                title  \
# 0  HOLLYWEIRD LIB SUSAN SARANDON Compares Muslim ...
# 1   Elijah Cummings Called Trump Out To His Face ...
# 2   Hillary Clinton Says Half Her Cabinet Will Be...
# 3  Russian bombing of U.S.-backed forces being di...
# 4  Britain says window to restore Northern Irelan...
#
#                                                 text                 date  \
# 0  There are two small problems with your analogy...         Dec 30, 2015
# 1  Buried in Trump s bonkers interview with New Y...        April 6, 2017
# 2  Women make up over 50 percent of this country,...       April 26, 2016
# 3  WASHINGTON (Reuters) - U.S. Defense Secretary ...  September 18, 2017
# 4  BELFAST (Reuters) - Northern Ireland s politic...   September 4, 2017
#
#   fake_or_factual
# 0       Fake News
# 1       Fake News
# 2       Fake News
# 3    Factual News
# 4    Factual News

# %%
import sheryanalysis as sh
sh.analyze(df)
# Out:
# 🔍 Basic Analysis Report
# ------------------------------------------------------------
# 📏 Shape: (198, 4)
# 🧱 Columns: ['title', 'text', 'date', 'fake_or_factual']
#
# ✅ No null values found
#
# 🔠 Categorical Columns: ['fake_or_factual']
#
# 📝 Text Columns: ['title', 'text', 'date']
# C:\Users\HARSHIT\anaconda3\Lib\site-packages\sheryanalysis\utils.py:103: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(sample)
# C:\Users\HARSHIT\anaconda3\Lib\site-packages\sheryanalysis\utils.py:103: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(sample)
# C:\Users\HARSHIT\anaconda3\Lib\site-packages\sheryanalysis\utils.py:103: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(sample)
# {'shape': (198, 4),
#  'columns': ['title', 'text', 'date', 'fake_or_factual'],
#  'dtypes': {'title': dtype('O'),
#   'text': dtype('O'),
#   'date': dtype('O'),
#   'fake_or_factual': dtype('O')},
#  'null_counts': {'title': 0, 'text': 0, 'date': 0, 'fake_or_factual': 0},
#  'total_rows': 198,
#  'column_types': {'categorical': ['fake_or_factual'],
#   'numerical': [],
#   'datetime': [],
#   'text': ['title', 'text', 'date']}}

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 198 entries, 0 to 197
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   title            198 non-null    object
#  1   text             198 non-null    object
#  2   date             198 non-null    object
#  3   fake_or_factual  198 non-null    object
# dtypes: object(4)
# memory usage: 6.3+ KB

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
sns.countplot(x=df["fake_or_factual"])
# Out:
# <Axes: xlabel='fake_or_factual', ylabel='count'>

# %%
df["title_length"] = df["title"].apply(len)
df["text_length"] = df["text"].apply(len)

# %%
sns.histplot(df["text_length"])
# Out:
# <Axes: xlabel='text_length', ylabel='Count'>

# %%
sns.boxplot(
    x=df["fake_or_factual"],
    y=df["text_length"]
)
# Out:
# <Axes: xlabel='fake_or_factual', ylabel='text_length'>

# %%
df["word_count"] = df["text"].apply(
    lambda x: len(x.split())
)
sns.boxplot(
    x=df["fake_or_factual"],
    y=df["word_count"]
)
# Out:
# <Axes: xlabel='fake_or_factual', ylabel='word_count'>
